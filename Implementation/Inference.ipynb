# %%
import model, matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

# %%
image_dir = './VOCdevkit/VOC2012/JPEGImages/2007_000033.jpg'
mask_dir = './VOCdevkit/VOC2012/SegmentationClass/2007_000033.png'
predict_dir = './predict.png'

num_classes = 21
gpu_id = 1
weight_file = './best.pt'

iter_max = 10
bi_w = 7
bi_xy_std = 50
bi_rgb_std = 4
pos_w = 3
pos_xy_std = 3

# %%
DeepLab_v1 = model.DeepLab_v1(num_classes=num_classes, gpu_id=gpu_id, weight_file=weight_file)

# %%
predict = DeepLab_v1.inference(image_dir=image_dir, iter_max=iter_max, 
                               bi_w=bi_w, bi_xy_std=bi_xy_std, bi_rgb_std=bi_rgb_std, 
                               pos_w=pos_w, pos_xy_std=pos_xy_std)

# %%
image = matplotlib.image.imread(image_dir)
plt.figure(figsize=(20, 10))
plt.axis('off')
plt.imshow(image)

# %%
mask = matplotlib.image.imread(mask_dir)
plt.figure(figsize=(20, 10))
plt.axis('off')
plt.imshow(mask)

# %%
plt.figure(figsize=(20, 10))
plt.axis('off')
plt.imshow(predict)
